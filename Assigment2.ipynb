# %%
# !pip install -qU langchain
# !pip install chromadb
# !pip install -U sentence-transformers
# !pip install nltk
# !pip install pypdf
# !pip install openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.9/922.9 kB 35.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.0 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.6/86.6 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 7.3 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import os
import getpass

import nltk
nltk.download('punkt')

from langchain.vectorstores import Chroma 

from langchain.memory import ConversationSummaryMemory, ChatMessageHistory
from langchain.llms import OpenAI

from langchain.document_loaders import PyPDFLoader
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
os.environ["OPENAI_API_KEY"] = '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'
llm = OpenAI(openai_api_key="OPENAI_API_KEY")

# %%
# pdf_loaders.append("/content/Business Project.pdf")

# %%
# files = [file for file in os.listdir('/content/drive/MyDrive/Colab Notebooks/Internship_pdf') if file.endswith('.pdf')]
# print(files)

pdf_loaders = []
pdf_loaders.append(PyPDFLoader("/content/MIS.pdf"))
pdf_loaders.append(PyPDFLoader("/content/Business Project.pdf"))

# for pdf_file in files:
#     pdf_loaders.append(PyPDFLoader("/content/drive/MyDrive/Colab Notebooks/Internship_pdf/" + pdf_file))

# print(pdf_loaders)
# pdf_loaders.append(PyPDFLoader("D:\Research Internship\LangChain Practise\Final Output\MIS.pdf"))

pages = pdf_loaders[0].load_and_split()
for i in range(len(pdf_loaders)):
    if i == 0 : continue
    pages += pdf_loaders[i].load_and_split()
    print(i)

print(pages[1])
# Out:
# 1
# page_content='2/22/2023 4Information is a Resource\n◼ItisScarce\n❑Available /Notavailable\n❑Constraints inavailing it\n◼IthasaCost\n❑Who decides the“cost”\n❑Which parameters canbeconsidered forcomputing “cost”\nofgathering information\n❑Relation between Cost andEffectiveness oftheInformation\n❑Cost:Fund? Man Power? Effort? Duration?' metadata={'source': '/content/MIS.pdf', 'page': 1}

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings()

# vectordb = Chroma.from_documents(pages, embedding = embeddings, persist_directory=".")

# %%
vectordb = Chroma.from_documents(pages, embedding = embeddings, persist_directory=".")

# %%
vectordb.persist()

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain

# %%
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
pdf_qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0) , vectordb.as_retriever(), memory=memory)

# %%
query = "What is information as a resource"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# ' Information as a resource is a limited and valuable asset that can be used to gain an advantage. It has a cost associated with gathering it, and the cost must be weighed against the potential uses of the information. There is also an opportunity cost factor involved if one does not process the information, as extraordinary scenarios may require taking risks that can lead to increased costs.'

# %%
query = "Who is Pm of India"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# " I don't know."

# %%
query = "What is Research Problem"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# ' A research problem is a statement that identifies a gap in knowledge or an issue that needs to be addressed. It is the foundation of a research project and should be framed in a way that is testable and measurable.'

# %%
query = "where is India"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# " I don't know."

# %%
query = "What is Richest Business in 2019"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# " I don't know."

# %%
query = "Who is swami vivekanda"
result = pdf_qa({"question": query})
print("Answer:")
result["answer"]
# Out:
# Answer:
# " I don't know."
